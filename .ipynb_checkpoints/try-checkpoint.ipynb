# %%
import pandas as pd
import scipy.io
import mpld3
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import os

mpld3.enable_notebook()

# %%
def preprocessing(x):
    
    def get_condition(x):
        x_mean = np.mean(x)
        x_min = min(x)
        return np.mean([x_min, x_min])
    
    def find_first_seq(x):
        pos = 0
        condition = get_condition(x)
        for i in range(len(x)-1):
            if abs(x[i] - x[i+1]) >= np.mean(x[:i]):
                break
            else: 
                pos += 1
        return np.mean(x[:pos]), pos
    
    def preprocess(x):
        dev, c = find_first_seq(x)
        for i in range(len(x)):
            x[i] -= dev
        return x
    
    def remove_negative_values(x):
        for i in range(len(x)):
            if x[i] < 0:
                x[i] = 0
        return x
    
    def filter_first_seq(x):
        ""
    
    return remove_negative_values(preprocess(x))


def interpolate(x):
    y = np.cos(-x**2/9.0)
    return scipy.interpolate.interp1d(x, range(len(x)), kind='cubic')

# %%
def load_data() -> dict:
    data_path = os.getcwd() + '\data'
    data = {}
    for file in os.listdir(data_path):
        if ".mat" in file:
            data[file.replace('.mat','')] = scipy.io.loadmat(data_path + "\\" + file)['tissue'][0][0][0]
    return data

# %%
def visualize_all():
    data = load_data()
    for k, v in data.items():
        if k == "exp17_roivelke_inp_tis_111007":
            v = v - np.mean(v[:25])
            p = sns.lineplot(x=range(len(v)), y=v)
            plt.figure()
            plt.grid(False) 
            plt.title(k) 
            plt.xlabel("time")
            plt.ylabel("intesity")
        else: 
            v = preprocessing(v)
            #p = sns.lineplot(x=range(len(v)), y=v)
            p = plt.scatter(x=range(len(v)),y=v)
            plt.figure()
            plt.grid(False) 
            plt.title(k) 
            plt.xlabel("time")
            plt.ylabel("intesity")

# %%
visualize_all()

# %%
data = load_data()

# %%
x = preprocessing(data['exp13_aifnova_inp_tis_111017'])
# Out:
# c:\Python311\Lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Python311\Lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
def remove_negative_values(x):
    max_s = max(x)/10
    for i in range(len(x)):
        if x[i] < 0 or x[i] < max_s:
            x[i] = 0.1
    return x

def pos_min_max(x):
    x = x.tolist()
    max_ind = x.index(np.max(x))
    min_ind = x.index(np.min(x)) 
    if min_ind < max_ind:
        return min_ind, max_ind
    
def ma(x):
    max_ = np.argmax(x)
    min_ = np.argmin(x)
    arr = np.where(x==min_)
    min_ = arr[0][len(arr[0])-1]
    x = x.tolist()
    max_ind = x.index(np.max(x))
    min_ind = x.index(np.min(x))
    return x[min_:max_], max_ind, min_ind

# %%
x_n = x[:20]

def ma(x):
    max_ = np.argmax(x)
    min_ = np.argmin(x)
    arr = np.where(x==min_)
    min_ = arr[0][len(arr[0])-1]
    return x[min_:max_], max_, min_

#x_s, max_pos, min_pos = ma(x_n)
#b = scipy.signal.resample(x_s, len(x_s) * 2)

#s = remove_negative_values(np.concatenate(x_n[:min_pos], b, x_n[max_pos:]), axis=0)
#min_ind, max_ind = pos_min_max(s)
#x_n = s[min_ind:max_ind]

b = scipy.signal.resample(x_n, len(x_n) * 2)
s = remove_negative_values(np.append(b,x_n[20:]))
min_ind, max_ind = pos_min_max(s)

#print(min_ind, max_ind)

s2 = s[min_ind:max_ind]

b = scipy.signal.resample(s2, len(s2) * 2)
s = remove_negative_values(np.append(b,s2[min_ind:max_ind],s[max_ind:]))

#plt.plot(np.append(b,x_n[20:]), )
plt.figure()
plt.scatter(range(len(s)),s)
plt.xlabel('fasd')
plt.ylabel('fdaf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[168], line 26
#      23 s2 = s[min_ind:max_ind]
#      25 b = scipy.signal.resample(s2, len(s2) * 2)
# ---> 26 s = remove_negative_values(np.append(b,s2[min_ind:max_ind],s[max_ind:]))
#      28 #plt.plot(np.append(b,x_n[20:]), )
#      29 plt.figure()
#
# File <__array_function__ internals>:180, in append(*args, **kwargs)
#
# File c:\Python311\Lib\site-packages\numpy\lib\function_base.py:5444, in append(arr, values, axis)
#    5442     values = ravel(values)
#    5443     axis = arr.ndim-1
# -> 5444 return concatenate((arr, values), axis=axis)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
x_n = x[:20]
signal, max_ind, min_ind = ma(x_n)
b = scipy.signal.resample(signal, len(signal) * 2)
#pos_min_max()
s = remove_negative_values(np.append(b,x_n[20:]))
#s = remove_negative_values(np.concatenate(x_n[:min_pos], b, x_n[max_pos:]), axis=0)

print(s)
# Out:
# [1.00000000e-01 1.49648853e+01 5.76736067e+01 6.66880103e+01
#  6.17981040e+01 8.13086387e+01 9.95755851e+01 8.94989196e+01
#  8.71947559e+01 1.13696690e+02 1.13698377e+02 5.37832844e+01]

# %%
xnew = interpolate(x[:15])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 xnew = interpolate(x[:15])
#
# Cell In[71], line 38, in interpolate(x)
#      36 def interpolate(x):
#      37     y = np.cos(-x**2/9.0)
# ---> 38     return scipy.interpolate.interp1d(x, range(len(x)), kind='cubic')
#
# File c:\Python311\Lib\site-packages\scipy\interpolate\_interpolate.py:571, in interp1d.__init__(***failed resolving arguments***)
#     568         yy = np.ones_like(self._y)
#     569         rewrite_nan = True
# --> 571 self._spline = make_interp_spline(xx, yy, k=order,
#     572                                   check_finite=False)
#     573 if rewrite_nan:
#     574     self._call = self.__class__._call_nan_spline
#
# File c:\Python311\Lib\site-packages\scipy\interpolate\_bsplines.py:1252, in make_interp_spline(x, y, k, t, bc_type, axis, check_finite)
# ...

# %%
plt.plot(x[:15], range(len(x[:15])), 'o', xnew, range(len(xnew)), '-')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plt.plot(x[:15], range(len(x[:15])), 'o', xnew, range(len(xnew)), '-')
#
# TypeError: object of type 'interp1d' has no len()

# %%
from scipy.integrate import simpson
from sklearn.metrics import auc
from numpy import trapz

dx = 1
area = trapz(x, dx=dx)
print("area =", area)

# Compute the area using the composite Simpson's rule.
area = simpson(x,dx=dx)
print("area =", area)

area = auc(range(len(x)),x)
print("area =", area)
# Out:
# area = 1848.2321079400372
# area = 1846.2314077545764
# area = 1848.2321079400372

# %%
from scipy.stats import lognorm
stddev = 0.859455801705594
mean = 0.418749176686875

#x = np.linspace(0,6,200)

# %%
f = auc/(np.sqrt(2*np.pi)*stddev*(t - t_0))*np.exp((np.log(t - t_0) - np.mean)-mu)**2 / (2 *stddev ** 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27064/2431239683.py in <module>
# ----> 1 f = auc/(np.sqrt(2*np.pi)*stddev*(t - t_0))*np.exp((np.log(t - t_0) - np.mean)-mu)**2 / (2 *stddev ** 2)
#
# TypeError: unsupported operand type(s) for /: 'function' and 'float'

# %%
p = lognorm.pdf(x, mean, stddev)

# %%
plt.plot(x, p, 'k', linewidth=2)
title = "LogNormal Distribution: Media: {:.2f} y Dev.Est: {:.2f}".format(mean, stddev)
plt.title(title)
plt.show()

# %%
plt.plot(x, range(len(x)), 'k', linewidth=2)
plt.show()

# %%
def solve_for_log_normal_parameters(mean, variance):
    sigma2 = np.log(variance/mean**2 + 1)
    mu = np.log(mean) - sigma2/2
    return mu, sigma2

# %%
mean, std = solve_for_log_normal_parameters(np.mean(x), np.std(x))

# %%
p = lognorm.pdf(x, mean, std)
plt.plot(x, p, 'k', linewidth=2)
title = "LogNormal Distribution: Media: {:.2f} y Dev.Est: {:.2f}".format(mean, stddev)
plt.title(title)
plt.show()
